# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 5.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.4/12.6 MB 8.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.6 MB 8.8 MB/s eta 0:00:01
#    ------------------------- -------------- 7.9/12.6 MB 9.2 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 9.4 MB/s eta 0:00:00
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# ...

# %%
import pandas as pd

# %%
df_customers = pd.read_csv("CSV files/Customers.csv" , encoding='ISO-8859-1')

# %%
df_customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
df_customers["State Code"].fillna('Unknown', inplace=True)
# Out:
# C:\Users\msi4_\AppData\Local\Temp\ipykernel_7288\46998460.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_customers["State Code"].fillna('Unknown', inplace=True)

# %%
df_customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
df_customers['Birthday'] = pd.to_datetime(df_customers['Birthday'])

# %%
df_customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
column_types = df_customers.dtypes
print(column_types)
# Out:
# CustomerKey             int64
# Gender                 object
# Name                   object
# City                   object
# State Code             object
# State                  object
# Zip Code               object
# Country                object
# Continent              object
# Birthday       datetime64[ns]
# dtype: object

# %%
# the proess are null values handled. Date time is converted from string to datetime

# %%
df_customers.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
df_customers.to_csv("Processed/customerprocessed.csv")

# %%
df_exchange = pd.read_csv("CSV files/Exchange_Rates.csv")

# %%
df_exchange
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df_exchange['Date'] = pd.to_datetime(df_exchange['Date'])

# %%
df_exchange.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
df_exchange.to_csv("Processed/exchangeproc.csv")

# %%
df_products = pd.read_csv("CSV files/Products.csv")

# %%
df_products.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
df_products.to_csv("Processed/productsproc.csv")

# %%
df_sales = pd.read_csv("CSV files/Sales.csv")

# %%
df_sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df_sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
# more than 50% of the data is lost in the delivery date. So it is safe to drop the column

# %%
df_sales.drop('Delivery Date', axis = 1,inplace = True)

# %%
df_sales.isnull().sum()
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
df_sales
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1   1/1/2016       265598        10        1304
# 1            366001          1   1/1/2016      1269051         0        1048
# 2            366001          2   1/1/2016      1269051         0        2007
# 3            366002          1   1/1/2016       266019         0        1106
# 4            366002          2   1/1/2016       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1  2/20/2021      1216913        43         632
# 62880       2243031          1  2/20/2021       511229         0          98
# 62881       2243032          1  2/20/2021       331277         0        1613
# 62882       2243032          2  2/20/2021       331277         0        1717
# 62883       2243032          3  2/20/2021       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
df_sales["Order Date"] = pd.to_datetime(df_sales['Order Date'])

# %%
df_sales
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
df_sales.to_csv("Processed/salesproc.csv")

# %%
df_stores = pd.read_csv("CSV files/Stores.csv")

# %%
df_stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
df_stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
df_stores[df_stores['Square Meters'].isnull()]
# Out:
#     StoreKey Country   State  Square Meters Open Date
# 66         0  Online  Online            NaN  1/1/2010

# %%
#since it is an online store the square meter doesn't serve purpose. so keeping it as zero

# %%
df_stores['Square Meters'].fillna(0, inplace=True)
# Out:
# C:\Users\msi4_\AppData\Local\Temp\ipykernel_7288\3900876548.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_stores['Square Meters'].fillna(0, inplace=True)

# %%
df_stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
df_stores ['Open Date'] = pd.to_datetime(df_stores['Open Date'])

# %%
df_stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# ...

# %%
df_stores.to_csv("Processed/storesproc.csv")

# %%
pip install mysql-connector-python
# Out:
# ...
#   Using cached mysql_connector_python-9.0.0-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# Using cached mysql_connector_python-9.0.0-cp312-cp312-win_amd64.whl (14.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Storing the processed data to MySQL Database

# %%
import mysql.connector

# %%
conn=mysql.connector.connect(user='root', password='root',
                              host='localhost', database = 'data_spark')
my_cursor = conn.cursor()

# %%
df=pd.read_csv("Processed\customerprocessed.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\sarom\AppData\Local\Temp\ipykernel_6336\3300778409.py:1: SyntaxWarning: invalid escape sequence '\c'
#   df=pd.read_csv("Processed\customerprocessed.csv")

# %%
df
# Out:
#        Unnamed: 0  CustomerKey  Gender               Name  \
# 0               0          301  Female      Lilly Harding
# 1               1          325  Female       Madison Hull
# 2               2          554  Female      Claire Ferres
# 3               3          786    Male  Jai Poltpalingada
# 4               4         1042    Male    Aidan Pankhurst
# ...           ...          ...     ...                ...
# 15261       15261      2099600  Female     Denisa Duková
# 15262       15262      2099618    Male   Justin Solórzano
# 15263       15263      2099758    Male    Svend Petrussen
# 15264       15264      2099862  Female       Lorenza Rush
# 15265       15265      2099937    Male   Zygmunt Kaminski
#
#                       City State Code              State Zip Code  \
# 0           WANDEARAH EAST         SA    South Australia     5523
# 1               MOUNT BUDD         WA  Western Australia     6522
# 2                WINJALLOK        VIC           Victoria     3380
# ...

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
create_table_sql = '''CREATE TABLE IF NOT EXISTS Customer (
    CustomerKey INT NOT NULL,
    Gender VARCHAR(255) NOT NULL,
    Name VARCHAR(255) NOT NULL,
    City VARCHAR(255) NOT NULL,
    StateCode VARCHAR(255) NULL, 
    State VARCHAR(255) NULL,
    ZipCode VARCHAR(255) NOT NULL, 
    Country VARCHAR(255) NOT NULL,
    Continent VARCHAR(255) NOT NULL,
    Birthday DATE 
)'''

                 

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
insert_sql = """INSERT INTO Customer(
                  CustomerKey,
                  Gender,
                  Name,
                  City,
                  StateCode,
                  State,
                  ZipCode,
                  Country,
                  Continent,
                  Birthday)
                VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""


# Convert DataFrame to list of tuples
data = df.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 15266 rows were inserted.

# %%
df1=pd.read_csv("Processed\exchangeproc.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\sarom\AppData\Local\Temp\ipykernel_6336\278261277.py:1: SyntaxWarning: invalid escape sequence '\e'
#   df1=pd.read_csv("Processed\exchangeproc.csv")

# %%
df1
# Out:
#        Unnamed: 0        Date Currency  Exchange
# 0               0  2015-01-01      USD    1.0000
# 1               1  2015-01-01      CAD    1.1583
# 2               2  2015-01-01      AUD    1.2214
# 3               3  2015-01-01      EUR    0.8237
# 4               4  2015-01-01      GBP    0.6415
# ...           ...         ...      ...       ...
# 11210       11210  2021-02-20      USD    1.0000
# 11211       11211  2021-02-20      CAD    1.2610
# 11212       11212  2021-02-20      AUD    1.2723
# 11213       11213  2021-02-20      EUR    0.8238
# 11214       11214  2021-02-20      GBP    0.7126
#
# [11215 rows x 4 columns]

# %%
df1.drop(df1.columns[0], axis=1, inplace=True)

# %%
df1
# Out:
#              Date Currency  Exchange
# 0      2015-01-01      USD    1.0000
# 1      2015-01-01      CAD    1.1583
# 2      2015-01-01      AUD    1.2214
# 3      2015-01-01      EUR    0.8237
# 4      2015-01-01      GBP    0.6415
# ...           ...      ...       ...
# 11210  2021-02-20      USD    1.0000
# 11211  2021-02-20      CAD    1.2610
# 11212  2021-02-20      AUD    1.2723
# 11213  2021-02-20      EUR    0.8238
# 11214  2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
conn=mysql.connector.connect(user='root', password='root',
                              host='localhost',
                              database='Data_spark')
my_cursor = conn.cursor()

create_table_sql = '''CREATE TABLE IF NOT EXISTS Exchange_Rates (
    Date   VARCHAR(255) NOT NULL,
    Currency VARCHAR(255) NOT NULL,
    Exchange VARCHAR(255) NOT NULL
)'''

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
insert_sql = """INSERT INTO Exchange_Rates(
                  Date,
                  Currency,
                  Exchange
                  )
                VALUES(%s, %s, %s)"""


# Convert DataFrame to list of tuples
data = df1.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 11215 rows were inserted.

# %%
df3=pd.read_csv("Processed\productsproc.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\sarom\AppData\Local\Temp\ipykernel_6336\3195222815.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df3=pd.read_csv("Processed\productsproc.csv")

# %%
df3
# Out:
#       Unnamed: 0  ProductKey                                   Product Name  \
# 0              0           1            Contoso 512MB MP3 Player E51 Silver
# 1              1           2              Contoso 512MB MP3 Player E51 Blue
# 2              2           3               Contoso 1G MP3 Player E100 White
# 3              3           4              Contoso 2G MP3 Player E200 Silver
# 4              4           5                 Contoso 2G MP3 Player E200 Red
# ...          ...         ...                                            ...
# 2512        2512        2513    Contoso Bluetooth Active Headphones L15 Red
# 2513        2513        2514  Contoso Bluetooth Active Headphones L15 White
# 2514        2514        2515             Contoso In-Line Coupler E180 White
# 2515        2515        2516             Contoso In-Line Coupler E180 Black
# 2516        2516        2517            Contoso In-Line Coupler E180 Silver
#
# ...

# %%
df3.drop(df3.columns[0], axis = 1, inplace=True)

# %%
df3
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
conn=mysql.connector.connect(user='root', password='root',
                              host='localhost',
                              database='Data_spark')
my_cursor = conn.cursor()
create_table_sql = '''CREATE TABLE IF NOT EXISTS Products (
    ProductKey INT NOT NULL,
    ProductName VARCHAR(255) NOT NULL,
    Brand VARCHAR(255) NOT NULL,
    Color VARCHAR(255) NOT NULL,
    UnitCostUSD VARCHAR(255) NULL, 
    UnitPriceUSD VARCHAR(255) NULL,
    SubcategoryKey INT NOT NULL, 
    Subcategory VARCHAR(255) NOT NULL,
    CategoryKey INT NOT NULL,
    Category VARCHAR(255) NOT NULL
    
)'''
          

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
insert_sql = """INSERT INTO Products(
                  ProductKey,
                  ProductName,
                  Brand,
                  Color,
                  UnitCostUSD,
                  UnitPriceUSD,
                  SubcategoryKey,
                  Subcategory,
                  CategoryKey,
                  Category
                  )
                VALUES(%s,%s, %s, %s,%s, %s, %s,%s, %s, %s)"""


# Convert DataFrame to list of tuples
data = df3.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 2517 rows were inserted.

# %%
df4=pd.read_csv("Processed\salesproc.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\sarom\AppData\Local\Temp\ipykernel_6336\1633533054.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df4=pd.read_csv("Processed\salesproc.csv")

# %%
df4
# Out:
#        Unnamed: 0  Order Number  Line Item  Order Date  CustomerKey  StoreKey  \
# 0               0        366000          1  2016-01-01       265598        10
# 1               1        366001          1  2016-01-01      1269051         0
# 2               2        366001          2  2016-01-01      1269051         0
# 3               3        366002          1  2016-01-01       266019         0
# 4               4        366002          2  2016-01-01       266019         0
# ...           ...           ...        ...         ...          ...       ...
# 62879       62879       2243030          1  2021-02-20      1216913        43
# 62880       62880       2243031          1  2021-02-20       511229         0
# 62881       62881       2243032          1  2021-02-20       331277         0
# 62882       62882       2243032          2  2021-02-20       331277         0
# 62883       62883       2243032          3  2021-02-20       331277         0
#
# ...

# %%
df4.drop(df4.columns[0],axis=1, inplace = True)

# %%
df4
# Out:
#        Order Number  Line Item  Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1  2016-01-01       265598        10        1304
# 1            366001          1  2016-01-01      1269051         0        1048
# 2            366001          2  2016-01-01      1269051         0        2007
# 3            366002          1  2016-01-01       266019         0        1106
# 4            366002          2  2016-01-01       266019         0         373
# ...             ...        ...         ...          ...       ...         ...
# 62879       2243030          1  2021-02-20      1216913        43         632
# 62880       2243031          1  2021-02-20       511229         0          98
# 62881       2243032          1  2021-02-20       331277         0        1613
# 62882       2243032          2  2021-02-20       331277         0        1717
# 62883       2243032          3  2021-02-20       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
conn=mysql.connector.connect(user='root', password='root',
                              host='localhost',
                              database='Data_spark')
my_cursor = conn.cursor()


create_table_sql = '''CREATE TABLE IF NOT EXISTS Sales (
    OrderNumber INT NOT NULL,
    LineItem INT NOT NULL,
    OrderDate VARCHAR(255) NOT NULL,
    CustomerKey INT NOT NULL,
    StoreKey INT NOT NULL, 
    ProductKey INT NOT NULL,
    Quantity INT NOT NULL, 
    CurrencyCode VARCHAR(255) NOT NULL
   
)'''     

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
insert_sql = """INSERT INTO Sales (
                  OrderNumber,
                  LineItem,
                  OrderDate,
                  CustomerKey,
                  StoreKey,
                  ProductKey,
                  Quantity,
                  CurrencyCode
                )
                VALUES(%s, %s, %s, %s, %s, %s, %s, %s)"""



# Convert DataFrame to list of tuples
data = df4.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 62884 rows were inserted.

# %%
df5=pd.read_csv("Processed\storesproc.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\sarom\AppData\Local\Temp\ipykernel_6336\1367700064.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df5=pd.read_csv("Processed\storesproc.csv")

# %%
df5
# Out:
#     Unnamed: 0  StoreKey        Country                         State  \
# 0            0         1      Australia  Australian Capital Territory
# 1            1         2      Australia            Northern Territory
# 2            2         3      Australia               South Australia
# 3            3         4      Australia                      Tasmania
# 4            4         5      Australia                      Victoria
# ..         ...       ...            ...                           ...
# 62          62        63  United States                          Utah
# 63          63        64  United States                 Washington DC
# 64          64        65  United States                 West Virginia
# 65          65        66  United States                       Wyoming
# 66          66         0         Online                        Online
#
#     Square Meters   Open Date
# 0           595.0  2008-01-01
# 1           665.0  2008-01-12
# 2          2000.0  2012-01-07
# ...

# %%
df5.drop(df5.columns[0],axis = 1, inplace = True)

# %%
conn=mysql.connector.connect(user='root', password='root',
                              host='localhost',
                              database='Data_spark')
my_cursor = conn.cursor()


create_table_sql = '''CREATE TABLE IF NOT EXISTS Store (
    StoreKey   INT NOT NULL,
    Country    VARCHAR(255) NOT NULL,
    State VARCHAR(255) NOT NULL,
    SquareMeters VARCHAR(255) NOT NULL, 
    OpenDate VARCHAR(255) NOT NULL
    
   
)'''     

# Execute table creation
my_cursor.execute(create_table_sql)

# %%
insert_sql = """INSERT INTO Store (
                  StoreKey,
                  Country,
                  State,
                  SquareMeters,
                  OpenDate
                )
                VALUES(%s, %s, %s, %s, %s)"""




# Convert DataFrame to list of tuples
data = df5.values.tolist()

# Execute batch insert
my_cursor.executemany(insert_sql, data)

# Commit the transaction using the connection object
conn.commit()

# Print number of rows inserted
print(my_cursor.rowcount, "rows were inserted.")

# Close the cursor and connection
my_cursor.close()
conn.close()
# Out:
# 67 rows were inserted.
